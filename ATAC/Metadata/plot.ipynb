# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from ALLCools.plot import *

# %%
cell_tidy_data = pd.read_msgpack('ATAC.cell_tidy_data.msg')
# Out:
# /home/hanliu/miniconda3/envs/clustering/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The read_msgpack is deprecated and will be removed in a future version.
# It is recommended to use pyarrow for on-the-wire transmission of pandas objects.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
cell_tidy_data.columns
# Out:
# Index(['sample', 'barcode', 'TN', 'UM', 'PP', 'UQ', 'CM', 'logUMI', 'landmark',
#        'umap-1', 'umap-2', 'cluster', 'L1', 'L2', 'L3', 'CellClass',
#        'MajorType', 'SubType', 'umap_0', 'umap_1'],
#       dtype='object')

# %%
fig, ax = plt.subplots(figsize=(10, 10), dpi=300)

categorical_scatter(ax=ax, data=cell_tidy_data, max_points=30000,
                    hue='CellClass', text_anno='MajorType', show_legend=True)

pass

# %%
cell_tidy_data['CellClass'].value_counts()
# Out:
# Glutamate    395858
# NonN         339156
# GABA         181109
# Name: CellClass, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10, 10), dpi=300)

categorical_scatter(ax=ax, data=cell_tidy_data, max_points=30000, palette='tab20',
                    hue='MajorType', text_anno='MajorType', show_legend=True)

pass

# %%
cell_tidy_data['MajorType'].value_counts()
# Out:
# IT      174754
# Ogc     117745
# Asc     112658
# Msn      65680
# GC       62462
# PIR      50541
# CT       46511
# Mgc      44226
# HIP      35748
# Opc      35175
# Sept     34455
# Mge      31872
# Vc       29352
# Olf      19423
# Cge      17592
# PT       12280
# NP        9303
# Mxd1      5708
# Hip       5006
# CLA       4259
# CRc        814
# Unk        559
# Name: MajorType, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10, 10), dpi=300)

categorical_scatter(ax=ax, data=cell_tidy_data, max_points=30000, palette='tab20',
                    hue='SubType', text_anno='SubType', show_legend=True)

pass
