# %%
import pandas as pd
import anndata
import numpy

# %% [markdown]
# ## Parameter

# %%
delta_dmr_rate_cutoff = 0.3

# %% [markdown]
# ## Load Data

# %%
dmr_hits = anndata.read_h5ad('RelatedClusterAndDMR.hypo_hits.h5ad')
dmr_hits = pd.DataFrame(dmr_hits.X.astype(bool).todense(), index=dmr_hits.obs_names, columns=dmr_hits.var_names)
dmr_hits.head()
# Out:
# index       CA1_Ak5  CA1_Chrm3  CA1_Kif26a  CA1_Ptprg  CA3_Cadm2  CA3_Efnb2  \
# index
# Subchr1_3     False      False       False      False      False      False
# Subchr1_8     False       True       False      False      False      False
# Subchr1_32    False      False       False      False      False      False
# Subchr1_37    False      False       False      False       True       True
# Subchr1_61    False      False       False      False      False      False
#
# index       CA3-St18_Epha5  CA3-St18_Nuak1  CA3-St18_Tead1  DG_dg-all  \
# index
# Subchr1_3            False           False           False      False
# Subchr1_8            False           False           False      False
# Subchr1_32           False           False           False      False
# Subchr1_37            True           False            True      False
# Subchr1_61           False           False           False       True
#
# index       DG-po_Bcl11a  DG-po_Calb2  DG-po_Kctd8  Gfra1_Gfra1  IG-CA2_Chrm3  \
# index
# Subchr1_3          False         True        False        False          True
# Subchr1_8          False        False        False        False          True
# Subchr1_32         False        False        False        False         False
# Subchr1_37         False         True         True        False         False
# Subchr1_61         False        False        False        False          True
#
# index       IG-CA2_Peak1  IG-CA2_Xpr1
# index
# Subchr1_3           True        False
# Subchr1_8           True        False
# Subchr1_32          True        False
# Subchr1_37         False        False
# Subchr1_61         False        False

# %%
dmr_rate = pd.read_msgpack('RelatedClusterAndDMR.mcg_rate.msg')
dmr_rate.head()
# Out:
# /home/hanliu/miniconda3/envs/clustering/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The read_msgpack is deprecated and will be removed in a future version.
# It is recommended to use pyarrow for on-the-wire transmission of pandas objects.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              CA1_Ak5  CA1_Chrm3  CA1_Kif26a  CA1_Ptprg  CA3_Cadm2  CA3_Efnb2  \
# index
# Subchr1_3   0.893162   0.879725    0.849057   0.897163   0.861111   0.919540
# Subchr1_8   0.905405   0.590909    0.974359   0.890052   0.872247   0.904762
# Subchr1_32  0.953846   0.947368    1.000000   0.945946   0.821429   1.000000
# Subchr1_37  0.716216   0.584270    0.846154   0.694444   0.248000   0.285714
# Subchr1_61  0.869048   0.574713    1.000000   0.688889   0.659341   0.700000
#
#             CA3-St18_Epha5  CA3-St18_Nuak1  CA3-St18_Tead1  DG_dg-all  \
# index
# Subchr1_3         0.821429        0.960000        0.868217   0.875000
# Subchr1_8         0.857143        0.959184        0.956522   0.812030
# Subchr1_32        1.000000        1.000000        0.954545   0.854369
# Subchr1_37        0.277778        0.562500        0.102564   0.669725
# Subchr1_61        0.611111        0.863636        0.708333   0.418182
#
#             DG-po_Bcl11a  DG-po_Calb2  DG-po_Kctd8  Gfra1_Gfra1  IG-CA2_Chrm3  \
# index
# Subchr1_3       1.000000     0.600000     0.636364     0.924528      0.456989
# Subchr1_8       0.800000     0.923077     1.000000     0.857143      0.342857
# Subchr1_32      0.909091     1.000000     1.000000     1.000000      0.800000
# Subchr1_37      0.500000     0.200000     0.166667     0.736842      0.794118
# Subchr1_61      1.000000     0.769231     0.500000     1.000000      0.321429
#
#             IG-CA2_Peak1  IG-CA2_Xpr1
# index
# Subchr1_3       0.592593     0.750000
# Subchr1_8       0.355263     0.656250
# Subchr1_32      0.657895     0.842105
# Subchr1_37      0.774194     0.700000
# Subchr1_61      0.618182     0.750000

# %%
dmg = pd.read_msgpack('RelatedDMG.msg')
dmg['cluster_from'] = dmg['cluster_from'].str.replace(' ', '_')
dmg['cluster_to'] = dmg['cluster_to'].str.replace(' ', '_')
dmg.head()
# Out:
#    pvals_adj                gene_id cluster_from cluster_to gene_name    -lgp  \
# 0        0.0   ENSMUSG00000098760.1    CA1_Chrm3  DG_dg-all    Gm2164  1000.0
# 1        0.0  ENSMUSG00000054728.16    CA1_Chrm3  DG_dg-all   Phactr1  1000.0
# 2        0.0  ENSMUSG00000034275.18    CA1_Chrm3  DG_dg-all    Igsf9b  1000.0
# 3        0.0  ENSMUSG00000027674.16    CA1_Chrm3  DG_dg-all     Pex5l  1000.0
# 4        0.0   ENSMUSG00000057716.6    CA1_Chrm3  DG_dg-all  Tmem178b  1000.0
#
#       AUROC
# 0  0.999939
# 1  0.999897
# 2  0.999874
# 3  0.999839
# 4  0.999798

# %%
corr = pd.read_msgpack('RelatedCorr.msg')
corr.head()
# Out:
#              DMR                  Gene      Corr chrom  DMR_to_gene_dist
# 1     Subchr1_79  ENSMUSG00000089699.1  0.314964  chr1         -405545.0
# 71   Subchr1_176  ENSMUSG00000104017.1  0.512181  chr1         -258484.0
# 73   Subchr1_176  ENSMUSG00000089699.1  0.508618  chr1         -347283.0
# 74   Subchr1_176  ENSMUSG00000103201.1  0.489546  chr1         -395203.0
# 141  Subchr1_246  ENSMUSG00000104017.1  0.377231  chr1         -211770.5

# %% [markdown]
# ## prepare DMR pairwise

# %%
pairwise_dmr_index = {}
for _, (cluster_from, cluster_to) in dmg[['cluster_from', 'cluster_to']].drop_duplicates().iterrows():
    # cluster_from is hypo, cluster_to is hyper
    rate_delta = (dmr_rate[cluster_to] - dmr_rate[cluster_from]) > delta_dmr_rate_cutoff
    # cluster_to is not hypo, cluster_from is hypo, and rate_delta > delta_dmr_rate_cutoff
    total_judge = (~dmr_hits[cluster_to]) & dmr_hits[cluster_from] & rate_delta

    # remaining dmr is sig hypo in cluster_from and hyper in cluster_to
    pairwise_dmr_index[(cluster_from, cluster_to)] = total_judge[total_judge].index

# %% [markdown]
# ## final DMG DMR for pairwise cluster

# %%
with pd.HDFStore('FinalDMGDMR.h5') as f:
    for (cluster_from, cluster_to), cluster_pair_df in dmg.groupby(
        ['cluster_from', 'cluster_to']):
        # first get related dmr and dmg separately
        cluster_pair_related_dmr = pairwise_dmr_index[(cluster_from, cluster_to)]
        cluster_pair_related_gene = cluster_pair_df['gene_id'].unique()
        
        # use them to filter corr
        cluster_pair_related_corr = corr[
            corr['DMR'].isin(cluster_pair_related_dmr)
            & corr['Gene'].isin(cluster_pair_related_gene)]
        
        # then use remained dmr and dmg as final list
        # the remaining DMR DMG is:
        # - sig hypo in one clsuter compare to another
        # - have sig correlateion
        cluster_pair_related_dmr = pd.Series(cluster_pair_related_corr['DMR'].unique())
        cluster_pair_related_gene = pd.Series(cluster_pair_related_corr['Gene'].unique())
        
        print(cluster_from, cluster_to, cluster_pair_related_dmr.size, cluster_pair_related_gene.size)
        this_dict = {}
        f[f'{cluster_from}/{cluster_to}/DMR'] = cluster_pair_related_dmr
        f[f'{cluster_from}/{cluster_to}/Gene'] = cluster_pair_related_gene
        f[f'{cluster_from}/{cluster_to}/Corr'] = cluster_pair_related_corr
# Out:
# CA1_Ak5 CA1_Chrm3 336 57
# CA1_Ak5 CA1_Kif26a 1025 99
# CA1_Ak5 CA1_Ptprg 35 8
# CA1_Ak5 CA3-St18_Epha5 3172 376
# CA1_Ak5 CA3-St18_Nuak1 2843 311
# CA1_Ak5 CA3-St18_Tead1 2617 293
# CA1_Ak5 CA3_Cadm2 2031 237
# CA1_Ak5 CA3_Efnb2 1405 152
# CA1_Ak5 DG-po_Bcl11a 1001 198
# CA1_Ak5 DG-po_Calb2 5347 455
# CA1_Ak5 DG-po_Kctd8 8139 612
# CA1_Ak5 DG_dg-all 3908 254
# CA1_Ak5 Gfra1_Gfra1 2654 246
# CA1_Ak5 IG-CA2_Chrm3 2533 317
# CA1_Ak5 IG-CA2_Peak1 1725 267
# CA1_Ak5 IG-CA2_Xpr1 5033 375
# CA1_Chrm3 CA1_Ak5 5961 121
# CA1_Chrm3 CA1_Kif26a 9900 275
# CA1_Chrm3 CA1_Ptprg 1785 60
# CA1_Chrm3 CA3-St18_Epha5 18584 720
# CA1_Chrm3 CA3-St18_Nuak1 25568 808
# CA1_Chrm3 CA3-St18_Tead1 21483 706
# CA1_Chrm3 CA3_Cadm2 13038 463
# CA1_Chrm3 CA3_Efnb2 24144 668
# CA1_Chrm3 DG-po_Bcl11a 9282 391
# CA1_Chrm3 DG-po_Calb2 22117 730
# CA1_Chrm3 DG-po_Kctd8 24932 824
# CA1_Chrm3 DG_dg-all 19886 434
# CA1_Chrm3 Gfra1_Gfra1 9136 314
# CA1_Chrm3 IG-CA2_Chrm3 12463 525
# CA1_Chrm3 IG-CA2_Peak1 13077 545
# CA1_Chrm3 IG-CA2_Xpr1 22294 603
# CA1_Kif26a CA1_Ak5 3902 186
# CA1_Kif26a CA1_Chrm3 2944 276
# CA1_Kif26a CA1_Ptprg 1739 153
# CA1_Kif26a CA3-St18_Epha5 12022 742
# CA1_Kif26a CA3-St18_Nuak1 12479 713
# CA1_Kif26a CA3-St18_Tead1 12320 722
# CA1_Kif26a CA3_Cadm2 11943 670
# CA1_Kif26a CA3_Efnb2 14129 699
# CA1_Kif26a DG-po_Bcl11a 7540 503
# CA1_Kif26a DG-po_Calb2 15888 887
# CA1_Kif26a DG-po_Kctd8 17316 901
# CA1_Kif26a DG_dg-all 14407 643
# CA1_Kif26a Gfra1_Gfra1 911 73
# CA1_Kif26a IG-CA2_Chrm3 11084 672
# CA1_Kif26a IG-CA2_Peak1 10998 674
# CA1_Kif26a IG-CA2_Xpr1 14139 673
# CA1_Ptprg CA1_Ak5 790 31
# Gfra1_Gfra1 DG-po_Kctd8 38006 981
# Gfra1_Gfra1 DG_dg-all 39520 928
# Gfra1_Gfra1 IG-CA2_Chrm3 30087 971
# Gfra1_Gfra1 IG-CA2_Peak1 31396 978
# Gfra1_Gfra1 IG-CA2_Xpr1 39283 982
# IG-CA2_Chrm3 CA1_Ak5 9570 237
# IG-CA2_Chrm3 CA1_Chrm3 6483 251
# IG-CA2_Chrm3 CA1_Kif26a 16259 371
# IG-CA2_Chrm3 CA1_Ptprg 8919 268
# IG-CA2_Chrm3 CA3-St18_Epha5 6982 342
# IG-CA2_Chrm3 CA3-St18_Nuak1 12197 440
# IG-CA2_Chrm3 CA3-St18_Tead1 10864 421
# IG-CA2_Chrm3 CA3_Cadm2 4833 214
# IG-CA2_Chrm3 CA3_Efnb2 13623 445
# IG-CA2_Chrm3 DG-po_Bcl11a 2500 126
# IG-CA2_Chrm3 DG-po_Calb2 14207 622
# IG-CA2_Chrm3 DG-po_Kctd8 13070 607
# IG-CA2_Chrm3 DG_dg-all 10681 259
# IG-CA2_Chrm3 Gfra1_Gfra1 15838 522
# IG-CA2_Chrm3 IG-CA2_Peak1 116 14
# IG-CA2_Chrm3 IG-CA2_Xpr1 4438 138
# IG-CA2_Peak1 CA1_Ak5 11905 249
# IG-CA2_Peak1 CA1_Chrm3 6959 285
# IG-CA2_Peak1 CA1_Kif26a 19168 420
# IG-CA2_Peak1 CA1_Ptprg 9448 266
# IG-CA2_Peak1 CA3-St18_Epha5 5927 347
# IG-CA2_Peak1 CA3-St18_Nuak1 10820 441
# IG-CA2_Peak1 CA3-St18_Tead1 9145 388
# IG-CA2_Peak1 CA3_Cadm2 3007 139
# IG-CA2_Peak1 CA3_Efnb2 12067 373
# IG-CA2_Peak1 DG-po_Bcl11a 4263 369
# IG-CA2_Peak1 DG-po_Calb2 13540 580
# IG-CA2_Peak1 DG-po_Kctd8 13220 563
# IG-CA2_Peak1 DG_dg-all 15561 497
# IG-CA2_Peak1 Gfra1_Gfra1 18222 526
# IG-CA2_Peak1 IG-CA2_Chrm3 126 19
# IG-CA2_Peak1 IG-CA2_Xpr1 10511 348
# IG-CA2_Xpr1 CA1_Ak5 5459 290
# IG-CA2_Xpr1 CA1_Chrm3 4060 340
# IG-CA2_Xpr1 CA1_Kif26a 8227 453
# IG-CA2_Xpr1 CA1_Ptprg 5402 342
# IG-CA2_Xpr1 CA3-St18_Epha5 4709 397
# IG-CA2_Xpr1 CA3-St18_Nuak1 7189 489
# IG-CA2_Xpr1 CA3-St18_Tead1 6941 464
# IG-CA2_Xpr1 CA3_Cadm2 4352 405
# IG-CA2_Xpr1 CA3_Efnb2 7250 484
# IG-CA2_Xpr1 DG-po_Bcl11a 1257 50
# IG-CA2_Xpr1 DG-po_Calb2 8618 754
# IG-CA2_Xpr1 DG-po_Kctd8 8910 768
# IG-CA2_Xpr1 DG_dg-all 2995 140
# IG-CA2_Xpr1 Gfra1_Gfra1 9253 681
# IG-CA2_Xpr1 IG-CA2_Chrm3 756 101
# IG-CA2_Xpr1 IG-CA2_Peak1 2201 296
