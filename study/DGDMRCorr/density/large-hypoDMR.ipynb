# %%
import pandas as pd
import numpy as np
import pybedtools

# %%
large_hypo_dmr = pybedtools.BedTool('../DG_DMR.decrease.mch_group.bed').merge(d=1000).to_dataframe()
length_filter = (large_hypo_dmr['end'] - large_hypo_dmr['start']) > 2000

large_hypo_dmr = large_hypo_dmr[length_filter].copy()
large_hypo_dmr.shape
# Out:
# (169, 3)

# %%
large_hypo_dmr = pybedtools.BedTool('../DG_DMR.increase.mch_group.bed').merge(d=1000).to_dataframe()
length_filter = (large_hypo_dmr['end'] - large_hypo_dmr['start']) > 2000

large_hypo_dmr = large_hypo_dmr[length_filter].copy()
large_hypo_dmr.shape
# Out:
# (334, 3)

# %%
large_hypo_dmr
# Out:
#       chrom      start        end
# 153    chr1   11018935   11020959
# 411    chr1   20843548   20845725
# 416    chr1   20892468   20898779
# 963    chr1   38439462   38441837
# 1188   chr1   42259911   42262916
# ...     ...        ...        ...
# 92978  chr9  107630168  107632337
# 92990  chr9  107699968  107702827
# 93043  chr9  109103109  109105807
# 93249  chr9  113798529  113800549
# 93766  chr9  123489252  123492678
#
# [334 rows x 3 columns]
