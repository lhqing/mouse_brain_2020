# %%
import pandas as pd
import numpy as np
import xarray as xr
import joblib
import seaborn as sns
import anndata
import matplotlib.pyplot as plt

# %%
from matplotlib import rc

labelsize = 6
linewidth = 0.1
rc('lines', linewidth=linewidth)
rc('axes', labelsize=labelsize, linewidth=linewidth)
rc('xtick', labelsize=labelsize)
rc('ytick', labelsize=labelsize)
rc('xtick.major', width=linewidth)
rc('ytick.major', width=linewidth)
rc('xtick.minor', width=linewidth-0.2)
rc('ytick.minor', width=linewidth-0.2)

# %% [markdown]
# ## Pairwise DMR

# %%
pairwise_dmr = anndata.read_h5ad(
    '/home/hanliu/project/mouse_rostral_brain/study/AssignGeneToTree/ExcDMR/PairwiseDMR.h5ad'
)

# %%
example_pair = ['CA1_Chrm3', 'CA3_Cadm2']
pair_id = pairwise_dmr.obs_names[
    pairwise_dmr.obs['cluster_a'].isin(example_pair)
    & pairwise_dmr.obs['cluster_b'].isin(example_pair)][0]
pair_id
# Out:
# '685'

# %%
related_dmr = pairwise_dmr.var_names[pairwise_dmr.var_vector(pair_id).astype(bool)]

# %%
related_dmr
# Out:
# Index(['Subchr1_133', 'Subchr1_150', 'Subchr1_224', 'Subchr1_225',
#        'Subchr1_228', 'Subchr1_342', 'Subchr1_343', 'Subchr1_411',
#        'Subchr1_514', 'Subchr1_516',
#        ...
#        'SubchrY_201', 'SubchrY_323', 'SubchrY_331', 'SubchrY_347',
#        'SubchrY_373', 'SubchrY_389', 'SubchrY_409', 'SubchrY_454',
#        'SubchrY_481', 'SubchrY_991'],
#       dtype='object', name='index', length=168991)

# %% [markdown]
# ## DMR Rate

# %%
with pd.HDFStore('/home/hanliu/project/mouse_rostral_brain/DMR/SubType/Total/DMRInfo.h5') as hdf:
    dmr_rate = hdf['Rate']

# %%
use_rate = dmr_rate.loc[related_dmr, example_pair].copy()
dmr_delta = (use_rate.iloc[:, 0] - use_rate.iloc[:, 1]).sort_values(ascending=False)
use_rate_up = use_rate.loc[dmr_delta[dmr_delta > 0.4].index]
use_rate_low = use_rate.loc[dmr_delta[dmr_delta < -0.4].index]

# %% [markdown]
# ## DMR Motif Hit Score

# %%
dmr_annot = anndata.read_h5ad(
    '/home/hanliu/project/mouse_rostral_brain/DMR/SubType/Total/MotifScan.h5ad'
)
# no need to filter score here, use cnorm bellow
# motif_cutoff = pd.Series(dmr_annot.X.max(axis=0).todense().A1 * mask_quantile_to_max, index=dmr_annot.var_names)

dmr_annot = dmr_annot[related_dmr, :].copy()
dmr_annot
# Out:
# AnnData object with n_obs × n_vars = 168991 × 719
#     obs: 'chrom', 'start', 'end'

# %% [markdown]
# ## Motif Enrichment

# %%
motif_gene_anno = pd.read_csv(
    '/home/hanliu/project/mouse_rostral_brain/study/MotifClustering/JASPAR2020_CORE_vertebrates_non-redundant.mouse_genes.with_motif_group.199.csv', 
    index_col=0
)
tf_class = pd.read_csv('/home/hanliu/ref/TFGene/TFClass/TFClass.with_mouse_gene_id.csv')
for tf_col in ['Class', 'Family', 'SubFamily']:
    gene_class_map = {}
    for _, (class_name, genes) in tf_class[[tf_col, 'EnsemblID']].iterrows():
        if isinstance(genes, float):
            continue
        for gene in genes.split(','):
            gene_class_map[gene] = class_name
    
    motif_gene_anno[tf_col] = motif_gene_anno['gene_ids'].apply(lambda i: gene_class_map.get(i.split('.')[0], ''))
motif_gene_anno.head()
# Out:
#           motif_name motif_genes                                     gene_ids  \
# motif_uid
# MA0006.1   Ahr::Arnt    Ahr,Arnt  ENSMUSG00000019256.17,ENSMUSG00000015522.18
# MA0854.1        Alx1        Alx1                        ENSMUSG00000036602.14
# MA0634.1        ALX3        ALX3                         ENSMUSG00000014603.3
# MA0853.1        Alx4        Alx4                        ENSMUSG00000040310.12
# MA0007.3          Ar          Ar                         ENSMUSG00000046532.8
#
#           gene_names    motif_group                                   Class  \
# motif_uid
# MA0006.1    Ahr,Arnt  MotifGroup178   Basic helix-loop-helix factors (bHLH)
# MA0854.1        Alx1    MotifGroup3                    Homeo domain factors
# MA0634.1        Alx3    MotifGroup3                    Homeo domain factors
# MA0853.1        Alx4    MotifGroup3                    Homeo domain factors
# MA0007.3          Ar   MotifGroup32  Nuclear receptors with C4 zinc fingers
#
#                               Family      SubFamily
# motif_uid
# MA0006.1                         PAS        PAS-AHR
# MA0854.1           Paired-related HD            ALX
# MA0634.1           Paired-related HD           TPRX
# MA0853.1           Paired-related HD            ALX
# MA0007.3   Steroid hormone receptors  GR-like(NR3C)

# %%
cluster_a, cluster_b = example_pair
motif_enrichment = pd.read_msgpack(
    f'/home/hanliu/project/mouse_rostral_brain/study/AssignGeneToTree/ExcDMR/TEMP/{cluster_a}-{cluster_b}.msg'
)

motif_enrichment = pd.concat(
    [motif_gene_anno.reindex(motif_enrichment.index), motif_enrichment],
    axis=1)
motif_enrichment['log2odds'] = np.log2(motif_enrichment['oddsratio'])
motif_enrichment = motif_enrichment[(motif_enrichment['-lgp'] > 10) & (
    motif_enrichment['log2odds'].abs() > 1)].copy()
# Out:
# /home/hanliu/miniconda3/envs/clustering/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The read_msgpack is deprecated and will be removed in a future version.
# It is recommended to use pyarrow for on-the-wire transmission of pandas objects.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
motif_enrichment.sort_values('log2odds')
# Out:
#               motif_name motif_genes  \
# MA0784.1          POU1F1      POU1F1
# MA0788.1          POU3F3      POU3F3
# MA0785.1          POU2F1      POU2F1
# MA0786.1          POU3F1      POU3F1
# MA0787.1          POU3F2      POU3F2
# MA0791.1          POU4F3      POU4F3
# MA0789.1          POU3F4      POU3F4
# MA0790.1          POU4F1      POU4F1
# MA0627.2          POU2F3      POU2F3
# MA0507.1          POU2F2      POU2F2
# MA1115.1          POU5F1      POU5F1
# MA1104.2           GATA6       GATA6
# MA0037.3           GATA3       GATA3
# MA0036.3           GATA2       GATA2
# MA0766.2           GATA5       GATA5
# MA0482.2           GATA4       GATA4
# MA0146.2             Zfx         Zfx
# MA1141.1       FOS::JUND    FOS,JUND
# MA1638.1           HAND2       HAND2
# MA0591.1     Bach1::Mafk  Bach1,Mafk
# MA1642.1  NEUROG2(var.2)     NEUROG2
# MA1109.1         NEUROD1     NEUROD1
#
#                                             gene_ids  gene_names  \
# MA0784.1                       ENSMUSG00000004842.18      Pou1f1
# MA0788.1                        ENSMUSG00000045515.3      Pou3f3
# MA0785.1                       ENSMUSG00000026565.18      Pou2f1
# MA0786.1                        ENSMUSG00000090125.3      Pou3f1
# MA0787.1                        ENSMUSG00000095139.2      Pou3f2
# MA0791.1                        ENSMUSG00000024497.4      Pou4f3
# MA0789.1                        ENSMUSG00000056854.4      Pou3f4
# MA0790.1                        ENSMUSG00000048349.9      Pou4f1
# MA0627.2                       ENSMUSG00000032015.16      Pou2f3
# MA0507.1                       ENSMUSG00000008496.19      Pou2f2
# MA1115.1                       ENSMUSG00000024406.16      Pou5f1
# MA1104.2                       ENSMUSG00000005836.10       Gata6
# MA0037.3                       ENSMUSG00000015619.10       Gata3
# MA0036.3                       ENSMUSG00000015053.14       Gata2
# MA0766.2                        ENSMUSG00000015627.5       Gata5
# MA0482.2                       ENSMUSG00000021944.15       Gata4
# MA0146.2                       ENSMUSG00000079509.10         Zfx
# MA1141.1  ENSMUSG00000021250.13,ENSMUSG00000071076.6    Fos,Jund
# MA1638.1                        ENSMUSG00000038193.4       Hand2
# MA0591.1  ENSMUSG00000025612.5,ENSMUSG00000018143.10  Bach1,Mafk
# MA1642.1                        ENSMUSG00000027967.8     Neurog2
# MA1109.1                        ENSMUSG00000034701.9     Neurod1
#
#             motif_group                                  Class  \
# MA0784.1   MotifGroup13                   Homeo domain factors
# MA0788.1   MotifGroup13                   Homeo domain factors
# MA0785.1   MotifGroup13                   Homeo domain factors
# MA0786.1   MotifGroup13                   Homeo domain factors
# MA0787.1   MotifGroup13                   Homeo domain factors
# MA0791.1   MotifGroup61                   Homeo domain factors
# MA0789.1   MotifGroup13                   Homeo domain factors
# MA0790.1   MotifGroup61                   Homeo domain factors
# MA0627.2   MotifGroup13                   Homeo domain factors
# MA0507.1   MotifGroup13                   Homeo domain factors
# MA1115.1   MotifGroup13                   Homeo domain factors
# MA1104.2    MotifGroup4      Other C4 zinc finger-type factors
# MA0037.3    MotifGroup4      Other C4 zinc finger-type factors
# MA0036.3    MotifGroup4      Other C4 zinc finger-type factors
# MA0766.2    MotifGroup4      Other C4 zinc finger-type factors
# MA0482.2    MotifGroup4      Other C4 zinc finger-type factors
# MA0146.2  MotifGroup126               C2H2 zinc finger factors
# MA1141.1    MotifGroup8    Basic leucine zipper factors (bZIP)
# MA1638.1    MotifGroup5  Basic helix-loop-helix factors (bHLH)
# MA0591.1    MotifGroup8    Basic leucine zipper factors (bZIP)
# MA1642.1    MotifGroup5  Basic helix-loop-helix factors (bHLH)
# MA1109.1    MotifGroup5  Basic helix-loop-helix factors (bHLH)
#
#                                      Family       SubFamily  oddsratio  \
# MA0784.1                                POU            POU1   0.157685
# MA0788.1                                POU            POU3   0.202542
# MA0785.1                                POU            POU2   0.213318
# MA0786.1                                POU            POU3   0.216134
# MA0787.1                                POU            POU3   0.217548
# MA0791.1                                POU            POU4   0.261539
# MA0789.1                                POU            POU3   0.263003
# MA0790.1                                POU            POU4   0.278921
# MA0627.2                                POU            POU2   0.378034
# MA0507.1                                POU            POU2   0.396296
# MA1115.1                                POU            POU5   0.425902
# MA1104.2                    C4-GATA-related     GATA double   0.439288
# MA0037.3                    C4-GATA-related     GATA double   0.476101
# MA0036.3                    C4-GATA-related     GATA double   0.490059
# MA0766.2                    C4-GATA-related     GATA double   0.491663
# MA0482.2                    C4-GATA-related     GATA double   0.498036
# MA0146.2  More than 3 adjacent zinc fingers         ZFX-ZFY   2.042447
# MA1141.1                        Fos-related             Fos   2.053733
# MA1638.1                        Tal-related           TWIST   2.089132
# MA0591.1                        Jun-related            NFE2   2.143282
# MA1642.1                        Tal-related  Neurogenin-ATO   3.724257
# MA1109.1                        Tal-related  Neurogenin-ATO   4.229872
#
#                 p_value  ...        -lgp  left_hit  left_no_hit  right_hit  \
# MA0784.1   2.483600e-88  ...   86.410947      82.0      68909.0      749.0
# MA0788.1  5.230025e-215  ...  212.628887     309.0      68682.0     2173.0
# MA0785.1   0.000000e+00  ...  300.000000     744.0      68247.0     4862.0
# MA0786.1   0.000000e+00  ...  300.000000     760.0      68231.0     4901.0
# MA0787.1   0.000000e+00  ...  300.000000     559.0      68432.0     3619.0
# MA0791.1   1.211735e-13  ...   12.232291      28.0      68963.0      155.0
# MA0789.1   0.000000e+00  ...  300.000000    1393.0      67598.0     7266.0
# MA0790.1   1.483290e-50  ...   48.791589     128.0      68863.0      662.0
# MA0627.2  1.198796e-279  ...  277.143707    1518.0      67473.0     5617.0
# MA0507.1  4.194794e-230  ...  227.696652    1400.0      67591.0     4967.0
# MA1115.1   0.000000e+00  ...  300.000000    4948.0      64043.0    15355.0
# MA1104.2  1.115384e-142  ...  140.527210    1135.0      67856.0     3668.0
# MA0037.3  3.350775e-288  ...  285.659518    3109.0      65882.0     9018.0
# MA0036.3  2.296511e-296  ...  293.782203    3545.0      65446.0     9953.0
# MA0766.2  3.565819e-268  ...  265.705055    3210.0      65781.0     9029.0
# MA0482.2  5.914910e-115  ...  112.927626    1350.0      67641.0     3853.0
# MA0146.2   2.480238e-24  ...   22.757378     483.0      68508.0      344.0
# MA1141.1   6.151345e-83  ...   81.044497    1726.0      67265.0     1234.0
# MA1638.1   0.000000e+00  ...  300.000000   24377.0      44614.0    20732.0
# MA0591.1   6.702831e-13  ...   11.510137     217.0      68774.0      147.0
# MA1642.1   0.000000e+00  ...  300.000000   13619.0      55372.0     6195.0
# MA1109.1   0.000000e+00  ...  300.000000    8971.0      60020.0     3413.0
#
#           right_no_hit  left_hit_rate  right_hit_rate   ClusterA   ClusterB  \
# MA0784.1       99251.0       0.001189         0.00749  CA1_Chrm3  CA3_Cadm2
# MA0788.1       97827.0       0.004479         0.02173  CA1_Chrm3  CA3_Cadm2
# MA0785.1       95138.0       0.010784         0.04862  CA1_Chrm3  CA3_Cadm2
# MA0786.1       95099.0       0.011016         0.04901  CA1_Chrm3  CA3_Cadm2
# MA0787.1       96381.0       0.008103         0.03619  CA1_Chrm3  CA3_Cadm2
# MA0791.1       99845.0       0.000406         0.00155  CA1_Chrm3  CA3_Cadm2
# MA0789.1       92734.0       0.020191         0.07266  CA1_Chrm3  CA3_Cadm2
# MA0790.1       99338.0       0.001855         0.00662  CA1_Chrm3  CA3_Cadm2
# MA0627.2       94383.0       0.022003         0.05617  CA1_Chrm3  CA3_Cadm2
# MA0507.1       95033.0       0.020293         0.04967  CA1_Chrm3  CA3_Cadm2
# MA1115.1       84645.0       0.071719         0.15355  CA1_Chrm3  CA3_Cadm2
# MA1104.2       96332.0       0.016451         0.03668  CA1_Chrm3  CA3_Cadm2
# MA0037.3       90982.0       0.045064         0.09018  CA1_Chrm3  CA3_Cadm2
# MA0036.3       90047.0       0.051384         0.09953  CA1_Chrm3  CA3_Cadm2
# MA0766.2       90971.0       0.046528         0.09029  CA1_Chrm3  CA3_Cadm2
# MA0482.2       96147.0       0.019568         0.03853  CA1_Chrm3  CA3_Cadm2
# MA0146.2       99656.0       0.007001         0.00344  CA1_Chrm3  CA3_Cadm2
# MA1141.1       98766.0       0.025018         0.01234  CA1_Chrm3  CA3_Cadm2
# MA1638.1       79268.0       0.353336         0.20732  CA1_Chrm3  CA3_Cadm2
# MA0591.1       99853.0       0.003145         0.00147  CA1_Chrm3  CA3_Cadm2
# MA1642.1       93805.0       0.197403         0.06195  CA1_Chrm3  CA3_Cadm2
# MA1109.1       96587.0       0.130031         0.03413  CA1_Chrm3  CA3_Cadm2
#
#           log2odds
# MA0784.1 -2.664881
# MA0788.1 -2.303709
# MA0785.1 -2.228919
# MA0786.1 -2.210002
# MA0787.1 -2.200593
# MA0791.1 -1.934902
# MA0789.1 -1.926848
# MA0790.1 -1.842071
# MA0627.2 -1.403411
# MA0507.1 -1.335351
# MA1115.1 -1.231407
# MA1104.2 -1.186763
# MA0037.3 -1.070660
# MA0036.3 -1.028973
# MA0766.2 -1.024257
# MA0482.2 -1.005679
# MA0146.2  1.030299
# MA1141.1  1.038249
# MA1638.1  1.062903
# MA0591.1  1.099821
# MA1642.1  1.896953
# MA1109.1  2.080614
#
# [22 rows x 21 columns]

# %%
def get_motif_score(motif_id):
    return pd.Series(dmr_annot.obs_vector(motif_id), index=dmr_annot.obs_names)

# %%
motif_ids = ['MA0789.1', 'MA1109.1']

# %%
motif_data = pd.DataFrame([get_motif_score(m) for m in motif_ids], index=motif_ids).T

# %%
motif_up = motif_data.loc[use_rate_up.index]
motif_low = motif_data.loc[use_rate_low.index]

# %%
motif_enrichment.loc[motif_ids, ['left_hit_rate', 'right_hit_rate']]
# Out:
#           left_hit_rate  right_hit_rate
# MA0789.1       0.020191         0.07266
# MA1109.1       0.130031         0.03413

# %% [markdown]
# ## Plot

# %%
fig = plt.figure(figsize=(0.6, 1.5), dpi=300)

gs = fig.add_gridspec(15, 3)

i = 0
motif_id = motif_ids[0]
ax_up = fig.add_subplot(gs[0:7, i])
ax_low = fig.add_subplot(gs[7:14, i])

ax = ax_up
ax.imshow(motif_up.loc[:, motif_id].values[:, None],
          aspect='auto',
          cmap='Blues',
          vmin=10,
          vmax=20)
ax.axis('off')
ax = ax_low
ax.imshow(motif_low.loc[:, motif_id].values[:, None],
          aspect='auto',
          cmap='Reds',
          vmin=10,
          vmax=20)
ax.axis('off')

i = 1
ax_up = fig.add_subplot(gs[0:7, i])
ax_up.text(0.5, 0.5, '...', fontsize=8, ha='center', va='center')
ax_low = fig.add_subplot(gs[7:14, i])
ax_low.text(0.5, 0.5, '...', fontsize=8, ha='center', va='center')
ax_up.axis('off')
ax_low.axis('off')



i = 2
motif_id = motif_ids[1]
ax_up = fig.add_subplot(gs[0:7, i])
ax_low = fig.add_subplot(gs[7:14, i])

ax = ax_up
ax.imshow(motif_up.loc[:, motif_id].values[:, None],
          aspect='auto',
          cmap='Reds',
          vmin=10,
          vmax=20)
ax.axis('off')
ax = ax_low
ax.imshow(motif_low.loc[:, motif_id].values[:, None],
          aspect='auto',
          cmap='Blues',
          vmin=10,
          vmax=20)
ax.axis('off')

fig.savefig('PairwiseDMR.motif_example.pdf')

# %%
from ALLCools.motif.utilities import *

# %%
motif_dict = meme_to_pfm_dict(
    '/home/hanliu/ref/MEME/selected_motifs_sets/JASPAR2020_CORE_vertebrates_non-redundant_pfms.meme',
    bits_scale=True)
# Out:
# /home/hanliu/miniconda3/envs/clustering/lib/python3.7/site-packages/ALLCools/motif/utilities.py:138: RuntimeWarning: divide by zero encountered in log2
#   information_content = (pfm * np.log2(pfm / 0.25)).sum(axis=1)

# %%
fig, axes = plt.subplots(figsize=(0.6, 0.1), ncols=2, dpi=300)

for motif_id, ax in zip(motif_ids, axes.flat):
    pfm = motif_dict[motif_id]
    plot_pfm(pfm, ax=ax, logo_kws=None)
    ax.axis('off')
fig.savefig('MotifLogo.pdf')

# %%
motif_gene_anno.loc[motif_ids]
# Out:
#           motif_name motif_genes              gene_ids gene_names  \
# motif_uid
# MA0789.1      POU3F4      POU3F4  ENSMUSG00000056854.4     Pou3f4
# MA1109.1     NEUROD1     NEUROD1  ENSMUSG00000034701.9    Neurod1
#
#             motif_group                                  Class       Family  \
# motif_uid
# MA0789.1   MotifGroup13                   Homeo domain factors          POU
# MA1109.1    MotifGroup5  Basic helix-loop-helix factors (bHLH)  Tal-related
#
#                 SubFamily
# motif_uid
# MA0789.1             POU3
# MA1109.1   Neurogenin-ATO
